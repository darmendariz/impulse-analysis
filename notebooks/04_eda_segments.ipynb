# %% [markdown]
# # EDA on `SegmentedDataset`

# %% [markdown]
# Segment each replay by kickoff reset events, then perform EDA on the resulting `SegmentedDataset`. Mostly just need to look at segment length outliers for preprocessing since feature distributions etc. will be the same.
