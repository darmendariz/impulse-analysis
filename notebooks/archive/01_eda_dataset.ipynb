# %% [markdown]
# Before analyzing individual time series, let's explore the full dataset first. The dataset is a collection of `.parquet` files, each consisting of an array of game state data of shape `(frames, features)` extracted from raw `.replay` files.

# %%
from impulse import ReplayDataset, ReplayData

import matplotlib.pyplot as plt

# %%
from pathlib import Path

project_root = Path('/Users/david/dev/impulse')
data_dir = project_root / 'replays/parsed'
db_path = project_root / 'impulse.db'

replays = ReplayDataset(db_path=str(db_path), data_dir=str(data_dir))

# %% [markdown]
# Let's check how many parsed replays we have:

# %%
len(replays)
# Out:
# Found 192 parsed replays in database
# 192

# %% [markdown]
# What does a `replay` object (as a member of a `ReplayDataset`) look like? It's a `ReplayData` dataclass with three attributes: `replay_id`, `frames`, and `metadata`. Metadata fields can also be accessed directly as attributes (e.g., `replay.team_size`):

# %%
sample_list = replays.load_sample(1)        # load a random replay
sample = sample_list[0]
print(type(sample))
print(f"replay_id: {type(sample.replay_id)}")
print(f"frames: {type(sample.frames)}")
print(f"metadata: {type(sample.metadata)}")
# Out:
# Loaded 1 replays
# <class 'impulse.replay_dataset.ReplayData'>
# replay_id: <class 'str'>
# frames: <class 'pandas.core.frame.DataFrame'>
# metadata: <class 'dict'>

# %%
sample.replay_id
# Out:
# '0918290B4C954DCD04EB2E918E2B31F7'

# %%
sample.frames.head()
# Out:
#    frame  current time  frame time  seconds remaining  Ball - position x  \
# 0      0     15.782539   15.782658              300.0        -241.339996
# 1      1     15.882540   15.882656              300.0        -565.049988
# 2      2     15.982540   15.982655              300.0       -1016.869995
# 3      3     16.082541   16.082653              300.0       -1402.859985
# 4      4     16.182541   16.182652              300.0       -1787.670044
#
#    Ball - position y  Ball - position z  Ball - linear velocity x  \
# 0         -41.520000         154.830002              -3890.010010
# 1         -38.220001         230.119995              -3880.110107
# 2         -33.599998         327.630005              -3866.250000
# 3         -29.639999         403.910004              -3854.479980
# 4         -25.680000         473.470001              -3842.719971
#
#    Ball - linear velocity y  Ball - linear velocity z  ...  \
# 0                 39.779999                934.619995  ...
# 1                 39.680000                878.099976  ...
# 2                 39.540001                799.229980  ...
# 3                 39.419998                731.849976  ...
# 4                 39.299999                664.669983  ...
#
#    p7_angular velocity z  p7_quaternion x  p7_quaternion y  p7_quaternion z  \
# 0                    NaN              NaN              NaN              NaN
# 1                    NaN              NaN              NaN              NaN
# 2                    NaN              NaN              NaN              NaN
# 3                    NaN              NaN              NaN              NaN
# 4                    NaN              NaN              NaN              NaN
#
#    p7_quaternion w  p7_boost level  p7_dodge active  p7_jump active  \
# 0              NaN             NaN              NaN             NaN
# 1              NaN             NaN              NaN             NaN
# 2              NaN             NaN              NaN             NaN
# 3              NaN             NaN              NaN             NaN
# 4              NaN             NaN              NaN             NaN
#
#    p7_double jump active  p7_player demolished by
# 0                    NaN                      NaN
# 1                    NaN                      NaN
# 2                    NaN                      NaN
# 3                    NaN                      NaN
# 4                    NaN                      NaN
#
# [5 rows x 161 columns]

# %%
sample.metadata
# Out:
# {'replay_id': '0918290B4C954DCD04EB2E918E2B31F7',
#  'frame_count': 3050,
#  'feature_count': 161,
#  'fps': 10.0,
#  'parsed_at': '2026-01-31T00:10:00.014867+00:00',
#  'source_file': '/Users/david/dev/impulse/replays/raw/rlcs/2024/World Championship/[1] Swiss Stage/Round 4/GGM1 vs QTPG/3dc4ade5-c401-4e78-bacf-5398810ee1a6.replay',
#  'replay_name': 'WORLDS AC QTPG vs GGM1 G3 2024-09-13.13.20',
#  'date': '2024-09-13 13-20-05',
#  'map': 'Stadium_P',
#  'match_type': 'Lan',
#  'team_size': 3,
#  'num_frames': 9731,
#  'duration_seconds': 305.0,
#  'team_0_score': None,
#  'team_1_score': 2,
#  'goals': [{'PlayerName': 'Chronic', 'PlayerTeam': 1, 'frame': 5963},
#   {'PlayerName': 'ApparentlyJack', 'PlayerTeam': 1, 'frame': 6849}],
#  'highlights': [{'BallName': 'Ball_TA_151',
#    'CarName': 'Car_TA_945',
#    'GoalActorName': 'None',
#    'frame': 546},
#   {'BallName': 'Ball_TA_151',
#    'CarName': 'Car_TA_940',
#    'GoalActorName': 'None',
#    'frame': 1505},
#   {'BallName': 'Ball_TA_151',
#    'CarName': 'Car_TA_943',
#    'GoalActorName': 'None',
#    'frame': 2036},
#   {'BallName': 'Ball_TA_151',
#    'CarName': 'Car_TA_944',
#    'GoalActorName': 'None',
#    'frame': 2844},
#   {'BallName': 'Ball_TA_151',
#    'CarName': 'Car_TA_941',
#    'GoalActorName': 'None',
#    'frame': 3505},
#   {'BallName': 'Ball_TA_151',
#    'CarName': 'Car_TA_948',
#    'GoalActorName': 'None',
#    'frame': 3826},
#   {'BallName': 'Ball_TA_151',
#    'CarName': 'Car_TA_942',
#    'GoalActorName': 'None',
#    'frame': 4523},
#   {'BallName': 'Ball_TA_151',
#    'CarName': 'Car_TA_940',
#    'GoalActorName': 'None',
#    'frame': 4825},
#   {'BallName': 'Ball_TA_151',
#    'CarName': 'Car_TA_948',
#    'GoalActorName': 'None',
#    'frame': 5192},
#   {'BallName': 'Ball_TA_151',
#    'CarName': 'Car_TA_940',
#    'GoalActorName': 'None',
#    'frame': 5240},
#   {'BallName': 'Ball_TA_151',
#    'CarName': 'Car_TA_948',
#    'GoalActorName': 'None',
#    'frame': 5951},
#   {'BallName': 'Ball_TA_151',
#    'CarName': 'Car_TA_942',
#    'GoalActorName': 'GoalVolume_TA_0',
#    'frame': 5963},
#   {'BallName': 'Ball_TA_151',
#    'CarName': 'Car_TA_958',
#    'GoalActorName': 'GoalVolume_TA_0',
#    'frame': 6849},
#   {'BallName': 'Ball_TA_155',
#    'CarName': 'Car_TA_970',
#    'GoalActorName': 'None',
#    'frame': 7814},
#   {'BallName': 'Ball_TA_155',
#    'CarName': 'Car_TA_969',
#    'GoalActorName': 'None',
#    'frame': 8665}],
#  'game_version': '240826.72292.458534',
#  'player_mapping': {'0': {'name': 'KCP Amphis',
#    'team': 0,
#    'steam_id': '76561198180452118',
#    'stats': {'Assists': 0,
#     'Goals': 0,
#     'Name': 'KCP Amphis',
#     'OnlineID': '76561198180452118',
#     'Platform': {'kind': 'OnlinePlatform', 'value': 'OnlinePlatform_Steam'},
#     'Saves': 1,
#     'Score': 188,
#     'Shots': 2,
#     'Team': 0,
#     'bBot': False}},
#   '1': {'name': 'KCP Fibérr',
#    'team': 0,
#    'steam_id': '76561198959074903',
#    'stats': {'Assists': 0,
#     'Goals': 0,
#     'Name': 'KCP Fibérr',
#     'OnlineID': '76561198959074903',
#     'Platform': {'kind': 'OnlinePlatform', 'value': 'OnlinePlatform_Steam'},
#     'Saves': 5,
#     'Score': 534,
#     'Shots': 4,
#     'Team': 0,
#     'bBot': False}},
#   '2': {'name': 'KCP Superlachie',
#    'team': 0,
#    'steam_id': '76561198996913568',
#    'stats': {'Assists': 0,
#     'Goals': 0,
#     'Name': 'KCP Superlachie',
#     'OnlineID': '76561198996913568',
#     'Platform': {'kind': 'OnlinePlatform', 'value': 'OnlinePlatform_Steam'},
#     'Saves': 3,
#     'Score': 311,
#     'Shots': 0,
#     'Team': 0,
#     'bBot': False}},
#   '3': {'name': 'Firstkiller',
#    'team': 1,
#    'steam_id': '76561198327846028',
#    'stats': {'Assists': 1,
#     'Goals': 0,
#     'Name': 'Firstkiller',
#     'OnlineID': '76561198327846028',
#     'Platform': {'kind': 'OnlinePlatform', 'value': 'OnlinePlatform_Steam'},
#     'Saves': 1,
#     'Score': 290,
#     'Shots': 1,
#     'Team': 1,
#     'bBot': False}},
#   '4': {'name': 'Chronic',
#    'team': 1,
#    'steam_id': '76561198799226283',
#    'stats': {'Assists': 0,
#     'Goals': 1,
#     'Name': 'Chronic',
#     'OnlineID': '76561198799226283',
#     'Platform': {'kind': 'OnlinePlatform', 'value': 'OnlinePlatform_Steam'},
#     'Saves': 1,
#     'Score': 371,
#     'Shots': 4,
#     'Team': 1,
#     'bBot': False}},
#   '5': {'name': 'ApparentlyJack',
#    'team': 1,
#    'steam_id': '76561199023677910',
#    'stats': {'Assists': 0,
#     'Goals': 1,
#     'Name': 'ApparentlyJack',
#     'OnlineID': '76561199023677910',
#     'Platform': {'kind': 'OnlinePlatform', 'value': 'OnlinePlatform_Steam'},
#     'Saves': 2,
#     'Score': 332,
#     'Shots': 5,
#     'Team': 1,
#     'bBot': False}},
#   '6': None,
#   '7': None},
#  'parsing_info': {'num_players': 6,
#   'num_frames_parsed': 3050,
#   'num_features': 166}}

# %% [markdown]
# ### Exploring a single replay dataframe

# %%
replay_id = sample.replay_id
df = sample.frames
metadata = sample.metadata

# %%
df.columns
# Out:
# Index(['frame', 'current time', 'frame time', 'seconds remaining',
#        'Ball - position x', 'Ball - position y', 'Ball - position z',
#        'Ball - linear velocity x', 'Ball - linear velocity y',
#        'Ball - linear velocity z',
#        ...
#        'p7_angular velocity z', 'p7_quaternion x', 'p7_quaternion y',
#        'p7_quaternion z', 'p7_quaternion w', 'p7_boost level',
#        'p7_dodge active', 'p7_jump active', 'p7_double jump active',
#        'p7_player demolished by'],
#       dtype='object', length=161)

# %%
df.shape
# Out:
# (3086, 161)

# %% [markdown]
# As seen above, the shape of the dataframe is `(frame_count, feature_count)`:

# %%
frame_count = metadata['frame_count']
feature_count = metadata['feature_count']
print(f"Frame count: {frame_count},\nFeature count: {feature_count}")
# Out:
# Frame count: 3086,
# Feature count: 161

# %%
df.describe()
# Out:
#              frame  current time   frame time  seconds remaining  \
# count  3086.000000   3086.000000  3086.000000        3086.000000
# mean   1542.500000    179.573863   179.590709         147.939728
# std     890.995791     94.173006    94.172926          88.354683
# min       0.000000     13.278890    13.310669           0.000000
# 25%     771.250000    106.202833   106.220886          71.000000
# 50%    1542.500000    183.330872   183.360016         148.000000
# 75%    2313.750000    260.460564   260.464027         225.000000
# max    3085.000000    337.590271   337.598877         300.000000
#
#        Ball - position x  Ball - position y  Ball - position z  \
# count        3086.000000        3086.000000        3086.000000
# mean         -347.505469         -92.035618         801.741202
# std          2567.896973        2959.139016         540.168875
# min         -4002.540039       -5036.240234          82.879997
# 25%         -2693.150024       -2795.889893         308.479996
# 50%          -521.174988        -168.764999         734.829987
# 75%          2062.710022        2472.510071        1222.887512
# max          4003.129883        5078.609863        1951.670044
#
#        Ball - linear velocity x  Ball - linear velocity y  \
# count               3086.000000               3086.000000
# mean                  -5.065907                -17.259164
# std                 1128.005462               1332.724275
# min                -3178.479980              -3022.060059
# 25%                 -730.990005              -1012.650009
# 50%                 -136.400002                -52.789999
# 75%                  626.050003               1055.799988
# max                 3270.320068               3507.020020
#
#        Ball - linear velocity z  ...  p7_angular velocity z  p7_quaternion x  \
# count               3086.000000  ...                    0.0              0.0
# mean                   0.538633  ...                    NaN              NaN
# std                  577.391917  ...                    NaN              NaN
# min                -1756.800049  ...                    NaN              NaN
# 25%                 -378.515007  ...                    NaN              NaN
# 50%                   -5.555000  ...                    NaN              NaN
# 75%                  372.470001  ...                    NaN              NaN
# max                 2137.860107  ...                    NaN              NaN
#
#        p7_quaternion y  p7_quaternion z  p7_quaternion w  p7_boost level  \
# count              0.0              0.0              0.0             0.0
# mean               NaN              NaN              NaN             NaN
# std                NaN              NaN              NaN             NaN
# min                NaN              NaN              NaN             NaN
# 25%                NaN              NaN              NaN             NaN
# 50%                NaN              NaN              NaN             NaN
# 75%                NaN              NaN              NaN             NaN
# max                NaN              NaN              NaN             NaN
#
#        p7_dodge active  p7_jump active  p7_double jump active  \
# count              0.0             0.0                    0.0
# mean               NaN             NaN                    NaN
# std                NaN             NaN                    NaN
# min                NaN             NaN                    NaN
# 25%                NaN             NaN                    NaN
# 50%                NaN             NaN                    NaN
# 75%                NaN             NaN                    NaN
# max                NaN             NaN                    NaN
#
#        p7_player demolished by
# count                      0.0
# mean                       NaN
# std                        NaN
# min                        NaN
# 25%                        NaN
# 50%                        NaN
# 75%                        NaN
# max                        NaN
#
# [8 rows x 161 columns]

# %% [markdown]
# The dataframe is padded with additional columns to accomodate features for up to 8 total players (two teams of four players). However, this replay is from a 3v3 RLCS match:

# %%
team_size = metadata['team_size']
team_size
# Out:
# 3

# %% [markdown]
# Therefore we can remove the extra columns. Let's drop the columns that consist exclusively of NaN values:

# %%
df.dropna(axis=1, how='all', inplace=True) 
df.shape
# Out:
# (3086, 125)

# %%
df.isnull().sum()
# Out:
# frame                      0
# current time               0
# frame time                 0
# seconds remaining          0
# Ball - position x          0
#                           ..
# p5_boost level             0
# p5_dodge active            0
# p5_jump active             0
# p5_double jump active      0
# p5_player demolished by    0
# Length: 125, dtype: int64

# %% [markdown]
# Now there are no NaN values in the dataframe.

# %% [markdown]
# ## Looking at dataset-level statistics

# %% [markdown]
# ### Replay length

# %%
frame_counts = [replay.frame_count for replay in replays]
duration_seconds = [replay.duration_seconds for replay in replays]

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

ax1.hist(frame_counts, bins=60)
ax1.set_title('Distribution of Frame Counts in Replays')
ax1.set_xlabel('Frame Count')
ax1.set_ylabel('Number of Replays')

ax2.hist(duration_seconds, bins=60)
ax2.set_title('Distribution of Replay Durations')
ax2.set_xlabel('Duration (seconds)')
ax2.set_ylabel('Number of Replays')
plt.tight_layout()
plt.show()

# %% [markdown]
# Since replay files are sampled at 10 FPS by the parser, it makes sense that these plots look identical and that the scale of their horizontal axes differs by a factor of 10.

# %% [markdown]
# This data comes from the RLCS 2024 World Championship, so each game should be a 3v3 game. We can verify that all replays have a `team_size` of 3:

# %%
team_sizes = [replay.team_size for replay in replays]
team_size_set = set(team_sizes)
team_size_set
